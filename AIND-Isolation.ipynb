# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# %%
objects = ('custom_1', 'custom_2', 'custom_3', 'basic')
y_pos = np.arange(len(objects))
performance = [77.43, 74.29, 72.14, 76.43]

# %%
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylim(70, 78)
plt.ylabel('Winning Percent')
plt.title('Heuristic function')
 
plt.show()

# %%
performance_1 = [20,18,14,15,15,14,11]
performance_2 = [18,18,11,16,16,14,15]
performance_3 = [20,15,15,12,16,14,12]
performance_4 = [18,16,11,16,17,14,9]

# %%
x = range(len(performance_1))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

# %%
ax1.scatter(x, performance_1, s=10, c='b', marker="s", label='custom_1')

# %%
ax1.scatter(x, performance_2, s=10, c='r', marker="o", label='custom_2')

# %%
ax1.scatter(x, performance_3, s=10, c='g', marker="+", label='custom_3')

# %%
ax1.scatter(x, performance_3, s=10, c='y', marker="o", label='basic')

# %%
plt.show()

# %%
plt.legend(loc='upper left');
plt.show()
# Out:
# /Users/haiyuancao/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
plt.plot(x, performance_1, 'ro-', x, performance_2, 'bo-', x, performance_3, 
         'go-', x, performance_4, 'yo-')
objects_2 = ['Random', 'MM_Null', 'MM_Open', 'MM_Improved', 'AB_Null', 'AB_Open', 'AB_Improved']
plt.xticks(x, objects_2)
plt.show()
